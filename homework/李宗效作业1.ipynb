# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei', 'SimHei', 'SimSun']

# %%
img = cv.imread('../images/small.png')
print(type(img))
print(img.shape)
print(img.size)
img
# Out:
# <class 'numpy.ndarray'>
# (5, 4, 3)
# 60
# array([[[  0,   0,   0],
#         [ 29,   1, 255],
#         [ 50, 203,   0],
#         [195,  69, 167]],
#
#        [[  0,   0, 255],
#         [ 29,   1, 255],
#         [ 50, 203,   0],
#         [195,  69, 167]],
#
#        [[255, 255, 255],
#         [ 93,  93, 174],
#         [255, 255, 145],
#         [  0,   0, 255]],
#
#        [[255,   0,   0],
#         [  2, 251, 169],
#         [231, 183, 203],
#         [ 11, 255, 170]],
#
#        [[  0, 255,   0],
#         [  2, 251, 169],
#         [231, 183, 203],
#         [ 11, 255, 170]]], dtype=uint8)

# %%
img[:, :, 2]
# Out:
# array([[  0, 255,   0, 167],
#        [255, 255,   0, 167],
#        [255, 174, 145, 255],
#        [  0, 169, 203, 170],
#        [  0, 169, 203, 170]], dtype=uint8)

# %%
img = cv.imread('../images/xiaoren.png')
cv.imshow('img', img)

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('gray', gray)

gray_green = img[:, :, 1] * 0.89
gray_green /= 255
cv.imshow('gray_green', gray_green)

gray_compute = img[:, :, 2] * 0.3 + img[:, :, 1] * 0.59 + img[:, :, 0] * 0.11
gray_compute /= 255
cv.imshow('gray_compute', gray_compute)

cv.waitKey(0)
# 释放所有资源
cv.destroyAllWindows()

# %%
img = cv.imread('../images/xiaoren.png', flags=1)
cv.namedWindow('image', cv.WINDOW_NORMAL)
cv.imshow('image', img)

plt.imshow(img[:, :, ::-1])
print(cv.waitKey(0))
# 释放所有资源
cv.destroyAllWindows()
# Out:
# 32

# %%
img = cv.imread('../images/xiaoren.png', flags=1)
cv.imwrite('../images/t1.png', img)
# Out:
# True

# %%
img = cv.imread('../images/xiaoren.png', flags=1)
cv.imshow('image', img)
k = cv.waitKey(0) & 0xFF
print(k)
if k == 27:
    print("Esc：", k)
else:
    cv.imwrite('../images/t2.png', img)
cv.destroyAllWindows()
# Out:
# 32

# %%
img = cv.imread('../images/xiaoren.png')
plt.imshow(img[:, :, ::-1])
plt.show()

img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %%
img = cv.imread('../images/t1.png')
cv.imshow('image', np.transpose(img, (1, 0, 2)))
cv.waitKey(0)
cv.destroyAllWindows()

# %%
cv.imshow('image', img[200:400, 100:300, :])
cv.waitKey(0)
cv.destroyAllWindows()

# %%
capture = cv.VideoCapture(0)
print(capture is not None)

size = (int(capture.get(cv.CAP_PROP_FRAME_WIDTH)),
        int(capture.get(cv.CAP_PROP_FRAME_HEIGHT)))
print(size)

success, frame = capture.read()
print(success)

while success and cv.waitKey(1) == -1:
    cv.imshow('frame', frame)
    success, frame = capture.read()
capture.release()
cv.destroyAllWindows()
# Out:
# True
# (0, 0)
# False

# %%
capture = cv.VideoCapture(0)
success = capture.set(cv.CAP_PROP_FRAME_WIDTH, 880)
if success:
    print("设置宽度成功")
success = capture.set(cv.CAP_PROP_FRAME_HEIGHT, 480)
if success:
    print("设置高度成功")

size = (int(capture.get(cv.CAP_PROP_FRAME_WIDTH)),
        int(capture.get(cv.CAP_PROP_FRAME_HEIGHT)))
print(size)
print(capture.get(cv.CAP_PROP_FPS))
# Out:
# (0, 0)
# 0.0

# %%
capture = cv.VideoCapture("../videos/v2.avi")
size = (int(capture.get(cv.CAP_PROP_FRAME_WIDTH)), int(capture.get(cv.CAP_PROP_FRAME_HEIGHT)))
print(size)
print(capture.get(cv.CAP_PROP_FPS))

success, frame = capture.read()

while success and cv.waitKey(60) == -1:
    cv.imshow('frame', frame)
    success, frame = capture.read()
capture.release()
cv.destroyAllWindows()
# Out:
# (848, 480)
# 25.0

# %%
img = np.zeros((512, 512, 3), np.uint8)
cv.line(img, (100, 50), (300, 100), (255, 0, 0), 2)
cv.line(img, (0, 0), (200, 511), (0, 0, 255), 5)

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = np.zeros((512, 512, 3), np.uint8)

cv.rectangle(img, (10, 10), (50, 320), (255, 0, 0), 5)
cv.rectangle(img, pt1=(360, 410), pt2=(460, 410), color=(0, 0, 255), thickness=2)

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = np.zeros((512, 512, 3), np.uint8)
cv.circle(img, (400, 200), 100, (0, 0, 255), 1)
cv.circle(img, (400, 200), 50, (0, 255, 255), 5)

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = np.zeros((512, 512, 3), np.uint8)
cv.ellipse(img, (210, 310), (200, 100), 0, 0, 180, (255, 0, 0), 5)
cv.ellipse(img, (210, 310), (100, 50), 0, 0, 360, (255, 0, 0), -1)
cv.ellipse(img, (210, 310), (50, 50), 0, 0, 360, (255, 255, 0), -1)
cv.ellipse(img, (210, 310), (25, 50), 0, 0, 360, (255, 0, 255), -1)
cv.ellipse(img, (210, 310), (25, 50), 90, 0, 360, (255, 0, 255), -1)
cv.ellipse(img, (210, 310), (25, 25), 0, 0, 360, (255, 255, 255), -1)
cv.ellipse(img, (210, 310), (25, 10), 0, 180, 360, (0, 0, 255), -1)

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = np.zeros((512, 512, 3), np.uint8)
pts = np.array([[10, 5],
                [20, 50],
                [70, 80],
                [50, 10]], np.int32)  # 4 个点
# cv.polylines(img, [pts], True, (255, 0, 0), 5)
cv.polylines(img, [pts], False, (255, 0, 0), 5)
cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = np.zeros((512, 512, 3), np.uint8)
cv.putText(img,
           text='OpenCV',
           org=(10, 150),
           fontFace=cv.FONT_HERSHEY_SIMPLEX,
           fontScale=4,
           color=(255, 255, 255),
           thickness=2,
           lineType=cv.LINE_AA)
cv.line(img, (10, 450), (200, 450), (0, 0, 255), 2)
cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = np.zeros((256, 256, 3), np.uint8)
plt.imshow(img[:, :, ::-1])

# %%
img = cv.imread("../images/xiaoren.png")
px = img[250, 300]
img.itemset((250, 300, 0), 100)

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread("../images/xiaoren.png")
box = img[0:95, 20:240]  # 截取的图
box2 = img[0:95, 280:500]  # 粘贴的位置
box2 = box2 * 0.8 + box * 0.2  # 叠加
img[0:95, 280:500] = box2  # 粘贴回去

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread("../images/xiaoren.png")
b, g, r = cv.split(img)

img = cv.merge((r, g, b))

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread('../images/opencv-logo.png')
print("原图大小：", img.shape)

replicate = cv.copyMakeBorder(img, 10, 10, 10, 10, cv.BORDER_REPLICATE)
reflect = cv.copyMakeBorder(img, 10, 10, 10, 10, cv.BORDER_REFLECT)
reflect101 = cv.copyMakeBorder(img, 10, 10, 10, 10, cv.BORDER_REFLECT_101)
wrap = cv.copyMakeBorder(img, 10, 10, 10, 10, cv.BORDER_WRAP)
constant = cv.copyMakeBorder(img, 10, 10, 10, 10, cv.BORDER_CONSTANT, value=[128, 128, 128])

fig, axex = plt.subplots(2, 3, figsize=(10, 8), dpi=100)
axex[0][0].imshow(img)
axex[0][1].imshow(replicate)
axex[0][2].imshow(reflect101)
axex[1][0].imshow(wrap)
axex[1][1].imshow(constant)
# Out:
# 原图大小： (99, 82, 3)

# %%
img1 = cv.imread("../images/xiaoren.png")
img2 = cv.imread("../images/opencv-logo.png")

img1 = cv.resize(img1, (300, 300))
img2 = cv.resize(img2, dsize=(300, 300))

dst = cv.addWeighted(src1=img1, alpha=0.3, src2=img2, beta=1.0, gamma=0)

dst = 0.3 * img1 + 1.0 * img2 + 0
dst = (dst / 255.0).clip(0.0, 1.0)

cv.imshow('image', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
a = img1 * 0.3 + img2 * 1.0
print("最大值：", np.max(a))

# 归一化
a = np.clip(a, a_min=0, a_max=255).astype(np.uint8)
print("数据类型：", a.dtype)

# 图像可视化
cv.imshow('image', a)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 最大值： 323.5
# 数据类型： uint8

# %%
img2 = cv.imread("../images/opencv-logo.png")
img2gray = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

ret, mask = cv.threshold(img2gray, 100, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)

cv.imshow('img2', img2)
# cv.imshow('img2gray', img2gray)
cv.imshow('mask', mask)
# cv.imshow('mask_inv', mask_inv)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
img1 = cv.imread("../images/xiaoren.png")
img2 = cv.imread("../images/opencv-logo.png")

rows1, cols1, _ = img1.shape
rows, cols, channels = img2.shape
start_rows = 50
end_rows = rows + 50
start_cols = cols1 - cols - 200
end_cols = cols1 - 200
roi = img1[start_rows:end_rows, start_cols:end_cols]

img2gray = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)
ret, mask = cv.threshold(img2gray, 10, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)

img1_bg = cv.bitwise_and(roi, roi, mask=mask_inv)
img2_fg = cv.bitwise_and(img2, img2, mask=mask)
dst = cv.add(img1_bg, img2_fg)

cv.imshow('img1_bg', img1_bg)
cv.imshow('img2_fg', img2_fg)
cv.imshow('dst', dst)

# cv.imshow('img1', img1)
# cv.imshow('mask_inv', mask_inv)
# cv.imshow('mask', mask)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
x = np.uint8([250])
y = np.uint8([10])
print(cv.add(x, y))
print(x + y)
# Out:
# [[255]]
# [4]

# %%
img = cv.imread("../images/small.png")
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
print(hsv.shape)
print(hsv[:, :, 0])
# Out:
# (5, 4, 3)
# [[  0 177  67 143]
#  [  0 177  67 143]
#  [  0   0  90   0]
#  [120  40 133  40]
#  [ 60  40 133  40]]

# %%
img[:, 0]
# Out:
# array([[  0,   0,   0],
#        [  0,   0, 255],
#        [255, 255, 255],
#        [255,   0,   0],
#        [  0, 255,   0]], dtype=uint8)

# %%
hsv[:, 0]
# Out:
# array([[  0,   0,   0],
#        [  0, 255, 255],
#        [  0,   0, 255],
#        [120, 255, 255],
#        [ 60, 255, 255]], dtype=uint8)

# %%
flags = [i for i in dir(cv) if i.startswith('COLOR_')]
print(len(flags))
# Out:
# 346

# %%
img = cv.imread('../images/opencv-logo.png')
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

cv.imshow('hsv', hsv)
cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread('../images/opencv-logo.png')
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

lower = np.array([165, 50, 50])
upper = np.array([180, 255, 255])

mask = cv.inRange(hsv, lower, upper)
print(mask.shape)

dst = cv.bitwise_and(img, img, mask=mask)
cv.imshow('hsv', hsv)
cv.imshow('img', img)
cv.imshow('mask', mask)
cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (99, 82)

# %%
img = cv.imread('../images/opencv-logo.png')
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

lower = np.array([165, 50, 50])
upper = np.array([180, 255, 255])
mask1 = cv.inRange(hsv, lower, upper)
lower = np.array([45, 50, 50])
upper = np.array([75, 255, 255])
mask2 = cv.inRange(hsv, lower, upper)

mask = cv.add(mask1, mask2)

dst = cv.bitwise_and(img, img, mask=mask)

mask3 = cv.bitwise_not(mask1)
dst2 = cv.bitwise_and(img, img, mask=mask3)

# cv.imshow('hsv', hsv)
# cv.imshow('mask', mask)
# cv.imshow('dst', dst)
# cv.imshow('mask1', mask1)
# cv.imshow('mask2', mask2)
cv.imshow('mask3', mask3)
cv.imshow('dst2', dst2)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img1 = cv.imread("../images/xiaoren.png")
rows, cols = img1.shape[:2]
res = cv.resize(img1, (2 * cols, 2 * rows), interpolation=cv.INTER_CUBIC)

res1 = cv.resize(img1, None, fx=0.5, fy=0.5)

fig, axes = plt.subplots(1, 3, figsize=(10, 8), dpi=100)
axes[0].imshow(img1[:, :, ::-1])
axes[1].imshow(res[:, :, ::-1])
axes[2].imshow(res1[:, :, ::-1])
plt.show()

# %%
img = cv.imread("../images/xiaoren.png")

old_height, old_width, _ = img.shape

new_weight = 250
new_height = int(old_height * 0.8)
dst = cv.resize(img, (new_weight, new_height))

cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img1 = cv.imread("../images/xiaoren.png")
rows, cols = img1.shape[:2]

M = np.float32([[1, 0, 100],
                [0, 1, 50]])
dst = cv.warpAffine(img1, M, (cols, rows))
dst = cv.warpAffine(img1, M, (2 * cols, 2 * rows))

fig, axes = plt.subplots(1, 2, figsize=(10, 8), dpi=100)
axes[0].imshow(img1[:, :, ::-1])
axes[1].imshow(dst[:, :, ::-1])
plt.show()

# %%
M = np.float32([
    [1, 0, 20],
    [0, 1, -10]
])
dst = cv.warpAffine(img, M, (img.shape[1], img.shape[0]))

cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
M = np.float32([
    [0.5, -0.1, 0],
    [0.1, 0.5, 0]
])
dst = cv.warpAffine(img, M, (img.shape[1], img.shape[0]))
cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img1 = cv.imread("../images/xiaoren.png")
rows, cols = img1.shape[:2]

M = cv.getRotationMatrix2D((cols / 2, rows / 2), 45, 0.5)
dst = cv.warpAffine(img1, M, (cols, rows))
cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread("../images/xiaoren.png")
rows, cols, _ = img.shape
M = cv.getRotationMatrix2D((cols / 2, rows / 2), -20, 0.5)
dst = cv.warpAffine(img, M, (cols, rows), borderValue=[255, 0, 0])

M = cv.getRotationMatrix2D((0, 0), 20, 0.5)
dst2 = cv.warpAffine(img, M, (cols, rows), borderValue=[128, 128, 128])

dst3 = cv.rotate(img, cv.ROTATE_90_COUNTERCLOCKWISE)

cv.imshow('dst', dst)
cv.imshow('dst2', dst2)
cv.imshow('dst3', dst3)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread("../images/xiaoren.png")
dst0 = cv.flip(img, 0)
dst1 = cv.flip(img, 1)

cv.imshow('dst', dst0)
cv.imshow('dst1', dst1)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread("../images/car3_plat.jpg")
h, w, _ = img.shape
M = cv.getRotationMatrix2D((0, 0), 20, 1)
dst = cv.warpAffine(img, M, (w + 30, h // 2))
cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread('../images/xiaoren.png')
rows, cols = img.shape[:2]

pts1 = np.float32([[50, 50],
                   [200, 50],
                   [50, 200]])
pts2 = np.float32([[100, 100],
                   [200, 50],
                   [100, 250]])
M = cv.getAffineTransform(pts1, pts2)
dst = cv.warpAffine(img, M, (cols, rows))
fig, axes = plt.subplots(1, 2, figsize=(10, 8), dpi=100)
axes[0].imshow(img[:, :, ::-1])
axes[1].imshow(dst[:, :, ::-1])
plt.show()

# %%
pts1 = np.float32([[170, 200], [350, 200], [170, 400]])  # 原图 [宽度, 高度]
pts2 = np.float32([[10, 50], [200, 50], [10, 300]])  # 新图
M = cv.getAffineTransform(pts1, pts2)
dst = cv.warpAffine(img, M, (cols, rows))
cv.imshow('dst', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread("../images/car3_plat.jpg")
h, w, _ = img.shape

M = cv.getRotationMatrix2D((0, 0), 20, 1)
dst = cv.warpAffine(img, M, (w + 30, h // 2))
h, w, _ = dst.shape

pts1 = np.float32([[15, 0], [245, 0], [250, 115]])
pts2 = np.float32([[0, 0], [300, 0], [300, 115]])
cv.circle(dst1, center=(15, 0), radius=5, color=(0, 255, 255), thickness=5)
cv.circle(dst1, center=(245, 0), radius=5, color=(0, 255, 255), thickness=5)
cv.circle(dst1, center=(250, 115), radius=5, color=(0, 255, 255), thickness=5)

M = cv.getAffineTransform(pts1, pts2)
dst2 = cv.warpAffine(dst, M, (300, h))

fig, axes = plt.subplots(1, 3, figsize=(10, 8), dpi=100)
axes[0].imshow(img[:, :, ::-1])
axes[1].imshow(dst[:, :, ::-1])
axes[2].imshow(dst2[:, :, ::-1])
plt.show()

# %%
img = cv.imread("../images/xiaoren.png")
rows, cols, _ = img.shape

pts1 = np.float32([[56, 65], [368, 52], [28, 387], [389, 390]])  # 原图像：随机
pts2 = np.float32([[0, 0], [300, 0], [0, 300], [300, 300]])
pts1_int = np.int32(pts1)

cv.polylines(img, [pts1_int], False, color=(0, 0, 255), thickness=5)

M = cv.getPerspectiveTransform(pts1, pts2)
dst = cv.warpPerspective(img, M, (500, 500))

fig, axes = plt.subplots(1, 2, figsize=(10, 8), dpi=100)
axes[0].imshow(img[:, :, ::-1])
axes[1].imshow(dst[:, :, ::-1])
plt.show()

# %%
img = cv.imread("../images/car3_plat.jpg")
h, w, _ = img.shape

M = cv.getRotationMatrix2D((0, 0), 20, 1)
dst = cv.warpAffine(img, M, (w + 30, h // 2))
h, w, _ = dst.shape

pts1 = np.float32([[15, 0], [245, 0], [250, 115]])
pts2 = np.float32([[0, 0], [300, 0], [300, 115]])
M = cv.getAffineTransform(pts1, pts2)
dst2 = cv.warpAffine(dst, M, (300, h))

pts1 = np.float32([[15, 0], [245, 0], [250, 115], [34, 100]])
pts2 = np.float32([[0, 0], [300, 0], [300, 115], [0, 115]])
M = cv.getPerspectiveTransform(pts1, pts2)
dst3 = cv.warpPerspective(dst, M, (300, h))

fig, axes = plt.subplots(1, 4, figsize=(10, 8), dpi=100)
axes[0].imshow(img[:, :, ::-1])
axes[1].imshow(dst[:, :, ::-1])
axes[2].imshow(dst2[:, :, ::-1])
axes[3].imshow(dst3[:, :, ::-1])
plt.show()

# %%
img = cv.imread('../images/xiaoren.png')

rows, cols = img.shape[:2]

# 创建变换矩阵
pts1 = np.float32([[56, 65], [368, 52], [28, 387], [389, 390]])
pts2 = np.float32([[100, 145], [300, 100], [80, 290], [310, 300]])

T = cv.getPerspectiveTransform(pts1, pts2)
dst = cv.warpPerspective(img, T, (cols, rows))

fig, axes = plt.subplots(1, 2, figsize=(10, 8), dpi=100)
axes[0].imshow(img[:, :, ::-1])
axes[0].set_title("原图")
axes[1].imshow(dst[:, :, ::-1])
axes[1].set_title("透射后结果")
plt.show()

# %%
img = cv.imread('../images/xiaoren.png')

up_img = cv.pyrUp(img)
img_1 = cv.pyrDown(img)

fig, axes = plt.subplots(1, 3, figsize=(10, 8), dpi=100)
axes[0].imshow(up_img[:, :, ::-1])
axes[0].set_title("上采样")
axes[1].imshow(img[:, :, ::-1])
axes[1].set_title("原图")
axes[2].imshow(img_1[:, :, ::-1])
axes[2].set_title("下采样")
plt.show()

# %%
img = np.arange(255, -1, -1).reshape(1, -1)
for i in range(255):
    img = np.append(img, np.arange(255, -1, -1).reshape(1, -1), axis=0)
img = img.astype(np.uint8)

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# img = cv.imread('../images/xiaoren.png')

ret, thresh1 = cv.threshold(img, 127, 255, cv.THRESH_BINARY)
ret, thresh2 = cv.threshold(img, 127, 255, cv.THRESH_BINARY_INV)
ret, thresh3 = cv.threshold(img, 127, 255, cv.THRESH_TRUNC)
ret, thresh4 = cv.threshold(img, 127, 255, cv.THRESH_TOZERO)
ret, thresh5 = cv.threshold(img, 127, 255, cv.THRESH_TOZERO_INV)

titles = ['Original Image', 'BINARY', 'BINARY_INV', 'TRUNC', 'TOZERO', 'TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(len(images)):
    plt.subplot(2, 3, i + 1)
    plt.imshow(images[i] / 255.0, 'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
img = cv.imread('../images/xiaoren.png', cv.IMREAD_GRAYSCALE)

ret, th1 = cv.threshold(img, 127, 255, cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img, 255, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, 11, 2)
th3 = cv.adaptiveThreshold(img, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 11, 2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
          'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(len(images)):
    plt.subplot(2, 2, i + 1)
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
# img1 = np.random.uniform(0, 255, (300, 300))
img1 = np.random.normal(150, 100, (300, 300))
img1 = np.clip(img1, 0, 255).astype(np.uint8)

img2 = np.zeros((300, 300), dtype=np.uint8)
img2[100:200, 100:200] = 255

img = cv.addWeighted(img1, 0.5, img2, 0.3, 0)

cv.imshow('img1', img1)
cv.imshow('img2', img2)
cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
ret1, th1 = cv.threshold(img, 127, 255, cv.THRESH_BINARY)

ret2, th2 = cv.threshold(img, 0, 255, cv.THRESH_BINARY + cv.THRESH_OTSU)

blur = cv.GaussianBlur(img, (5, 5), 0)
ret3, th3 = cv.threshold(blur, 0, 255, cv.THRESH_BINARY + cv.THRESH_OTSU)

images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ["Original Noisy Image", "Histogram", "Global Thresholding(v=127)",
          "Original Noisy Image", "Histogram", f"Otsu's Thresholding(v={ret2})",
          "Gaussian filtered Image", "Histogram", f"Otsu's Thresholding(v={ret3})"]

for i in range(3):
    # 原始图
    plt.subplot(3, 3, i * 3 + 1)  # 第 1 列
    plt.imshow(images[i * 3], 'gray')  # 灰度图
    plt.title(titles[i * 3])
    plt.xticks([])
    plt.yticks([])

    # 直方图
    plt.subplot(3, 3, i * 3 + 2)  # 第 2 列
    plt.hist(images[i * 3].ravel(), 256)
    plt.title(titles[i * 3 + 1])
    # plt.xticks([])
    plt.yticks([])

    # 二值化后的图
    plt.subplot(3, 3, i * 3 + 3)  # 第 3 列
    plt.imshow(images[i * 3 + 2], 'gray')
    plt.title(titles[i * 3 + 2])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
img3 = img.copy()
cv.rectangle(img3, (40, 40), (50, 50), (255, 0, 0), thickness=1)
cv.rectangle(img3, pt1=(95, 110), pt2=(105, 120), color=(255, 0, 0), thickness=1)

cv.imshow('img3', img3)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img[40:50, 40:50]
# Out:
# array([[122, 108,  94,   0,  76,  86,  26, 112,  38,  46],
#        [ 44,  88, 128,  82, 128, 128,  88, 128,  98,  84],
#        [ 13,  38,  48,  41, 126,  96,  48,   0,  48, 118],
#        [  0,  42,  78,   8,   4, 115,  82, 100,  16,  46],
#        [ 74,  58, 110, 106, 128,  77,  84, 128, 128,   6],
#        [ 88, 128, 122, 108,   0,  33,   0,  48,  72, 128],
#        [125, 103,  71, 128,  48,  38,   0,  98, 128,  34],
#        [ 96,  30,  76,   0,  12,  96,  56,  54, 123,  52],
#        [128, 128,  96,   0,  62, 128,  87,  50,  81,  30],
#        [106,   0, 112,  24,  54,  90,  24,  41,   0,  40]], dtype=uint8)

# %%
blur[40:50, 40:50]
# Out:
# array([[85, 90, 83, 75, 78, 82, 81, 80, 75, 70],
#        [65, 73, 76, 78, 87, 90, 82, 76, 74, 72],
#        [48, 55, 64, 71, 82, 87, 79, 70, 67, 68],
#        [50, 56, 64, 68, 74, 80, 79, 73, 67, 64],
#        [67, 76, 82, 79, 70, 67, 71, 76, 75, 67],
#        [84, 93, 94, 83, 63, 51, 55, 71, 80, 71],
#        [93, 93, 85, 70, 55, 46, 51, 69, 79, 71],
#        [94, 86, 70, 55, 53, 58, 62, 69, 72, 68],
#        [90, 84, 67, 53, 57, 67, 65, 60, 60, 64],
#        [84, 81, 72, 63, 63, 62, 55, 50, 55, 65]], dtype=uint8)
